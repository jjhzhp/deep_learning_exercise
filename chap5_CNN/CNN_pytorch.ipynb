# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
with torch.no_grad():
    test_x = torch.unsqueeze(test_data.data, dim=1).type(torch.FloatTensor)[:500] / 255.
test_y = test_data.targets[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,
                out_channels=32,
                kernel_size=7,
                stride=1,
                padding=3,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of conv2 to (batch_size, 7*7*64)
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2, dim=1)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# ========== 20 ===== ===== test accuracy is  0.096 ==========
# ========== 40 ===== ===== test accuracy is  0.3 ==========
# ========== 60 ===== ===== test accuracy is  0.378 ==========
# ========== 80 ===== ===== test accuracy is  0.522 ==========
# ========== 100 ===== ===== test accuracy is  0.588 ==========
# ========== 120 ===== ===== test accuracy is  0.606 ==========
# ========== 140 ===== ===== test accuracy is  0.642 ==========
# ========== 160 ===== ===== test accuracy is  0.7 ==========
# ========== 180 ===== ===== test accuracy is  0.73 ==========
# ========== 200 ===== ===== test accuracy is  0.746 ==========
# ========== 220 ===== ===== test accuracy is  0.8 ==========
# ========== 240 ===== ===== test accuracy is  0.814 ==========
# ========== 260 ===== ===== test accuracy is  0.814 ==========
# ========== 280 ===== ===== test accuracy is  0.826 ==========
# ========== 300 ===== ===== test accuracy is  0.854 ==========
# ========== 320 ===== ===== test accuracy is  0.852 ==========
# ========== 340 ===== ===== test accuracy is  0.872 ==========
# ========== 360 ===== ===== test accuracy is  0.86 ==========
# ========== 380 ===== ===== test accuracy is  0.87 ==========
# ========== 400 ===== ===== test accuracy is  0.888 ==========
# ========== 420 ===== ===== test accuracy is  0.872 ==========
# ========== 440 ===== ===== test accuracy is  0.886 ==========
# ========== 460 ===== ===== test accuracy is  0.878 ==========
# ========== 480 ===== ===== test accuracy is  0.878 ==========
# ========== 500 ===== ===== test accuracy is  0.912 ==========
# ========== 520 ===== ===== test accuracy is  0.89 ==========
# ========== 540 ===== ===== test accuracy is  0.884 ==========
# ========== 560 ===== ===== test accuracy is  0.9 ==========
# ========== 580 ===== ===== test accuracy is  0.902 ==========
# ========== 600 ===== ===== test accuracy is  0.906 ==========
# ========== 620 ===== ===== test accuracy is  0.912 ==========
# ========== 640 ===== ===== test accuracy is  0.91 ==========
# ========== 660 ===== ===== test accuracy is  0.898 ==========
# ========== 680 ===== ===== test accuracy is  0.926 ==========
# ========== 700 ===== ===== test accuracy is  0.928 ==========
# ========== 720 ===== ===== test accuracy is  0.912 ==========
# ========== 740 ===== ===== test accuracy is  0.918 ==========
# ========== 760 ===== ===== test accuracy is  0.914 ==========
# ========== 780 ===== ===== test accuracy is  0.92 ==========
# ========== 800 ===== ===== test accuracy is  0.922 ==========
# ========== 820 ===== ===== test accuracy is  0.916 ==========
# ========== 840 ===== ===== test accuracy is  0.934 ==========
# ========== 860 ===== ===== test accuracy is  0.934 ==========
# ========== 880 ===== ===== test accuracy is  0.924 ==========
# ========== 900 ===== ===== test accuracy is  0.934 ==========
# ========== 920 ===== ===== test accuracy is  0.91 ==========
# ========== 940 ===== ===== test accuracy is  0.928 ==========
# ========== 960 ===== ===== test accuracy is  0.93 ==========
# ========== 980 ===== ===== test accuracy is  0.934 ==========
# ========== 1000 ===== ===== test accuracy is  0.926 ==========
# ========== 1020 ===== ===== test accuracy is  0.93 ==========
# ========== 1040 ===== ===== test accuracy is  0.93 ==========
# ========== 1060 ===== ===== test accuracy is  0.93 ==========
# ========== 1080 ===== ===== test accuracy is  0.934 ==========
# ========== 1100 ===== ===== test accuracy is  0.952 ==========
# ========== 1120 ===== ===== test accuracy is  0.938 ==========
# ========== 1140 ===== ===== test accuracy is  0.932 ==========
# ========== 1160 ===== ===== test accuracy is  0.958 ==========
# ========== 1180 ===== ===== test accuracy is  0.936 ==========
# ========== 20 ===== ===== test accuracy is  0.94 ==========
# ========== 40 ===== ===== test accuracy is  0.942 ==========
# ========== 60 ===== ===== test accuracy is  0.95 ==========
# ========== 80 ===== ===== test accuracy is  0.942 ==========
# ========== 100 ===== ===== test accuracy is  0.958 ==========
# ========== 120 ===== ===== test accuracy is  0.948 ==========
# ========== 140 ===== ===== test accuracy is  0.932 ==========
# ========== 160 ===== ===== test accuracy is  0.942 ==========
# ========== 180 ===== ===== test accuracy is  0.944 ==========
# ========== 200 ===== ===== test accuracy is  0.946 ==========
# ========== 220 ===== ===== test accuracy is  0.936 ==========
# ========== 240 ===== ===== test accuracy is  0.94 ==========
# ========== 260 ===== ===== test accuracy is  0.934 ==========
# ========== 280 ===== ===== test accuracy is  0.952 ==========
# ========== 300 ===== ===== test accuracy is  0.944 ==========
# ========== 320 ===== ===== test accuracy is  0.95 ==========
# ========== 340 ===== ===== test accuracy is  0.956 ==========
# ========== 360 ===== ===== test accuracy is  0.956 ==========
# ========== 380 ===== ===== test accuracy is  0.966 ==========
# ========== 400 ===== ===== test accuracy is  0.958 ==========
# ========== 420 ===== ===== test accuracy is  0.94 ==========
# ========== 440 ===== ===== test accuracy is  0.944 ==========
# ========== 460 ===== ===== test accuracy is  0.96 ==========
# ========== 480 ===== ===== test accuracy is  0.95 ==========
# ========== 500 ===== ===== test accuracy is  0.962 ==========
# ========== 520 ===== ===== test accuracy is  0.952 ==========
# ========== 540 ===== ===== test accuracy is  0.952 ==========
# ========== 560 ===== ===== test accuracy is  0.954 ==========
# ========== 580 ===== ===== test accuracy is  0.96 ==========
# ========== 600 ===== ===== test accuracy is  0.944 ==========
# ========== 620 ===== ===== test accuracy is  0.95 ==========
# ========== 640 ===== ===== test accuracy is  0.95 ==========
# ========== 660 ===== ===== test accuracy is  0.958 ==========
# ========== 680 ===== ===== test accuracy is  0.962 ==========
# ========== 700 ===== ===== test accuracy is  0.954 ==========
# ========== 720 ===== ===== test accuracy is  0.954 ==========
# ========== 740 ===== ===== test accuracy is  0.958 ==========
# ========== 760 ===== ===== test accuracy is  0.96 ==========
# ========== 780 ===== ===== test accuracy is  0.96 ==========
# ========== 800 ===== ===== test accuracy is  0.962 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.952 ==========
# ========== 860 ===== ===== test accuracy is  0.962 ==========
# ========== 880 ===== ===== test accuracy is  0.956 ==========
# ========== 900 ===== ===== test accuracy is  0.974 ==========
# ========== 920 ===== ===== test accuracy is  0.954 ==========
# ========== 940 ===== ===== test accuracy is  0.966 ==========
# ========== 960 ===== ===== test accuracy is  0.964 ==========
# ========== 980 ===== ===== test accuracy is  0.968 ==========
# ========== 1000 ===== ===== test accuracy is  0.954 ==========
# ========== 1020 ===== ===== test accuracy is  0.96 ==========
# ========== 1040 ===== ===== test accuracy is  0.954 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.968 ==========
# ========== 1100 ===== ===== test accuracy is  0.96 ==========
# ========== 1120 ===== ===== test accuracy is  0.958 ==========
# ========== 1140 ===== ===== test accuracy is  0.964 ==========
# ========== 1160 ===== ===== test accuracy is  0.968 ==========
# ========== 1180 ===== ===== test accuracy is  0.956 ==========
# ========== 20 ===== ===== test accuracy is  0.966 ==========
# ========== 40 ===== ===== test accuracy is  0.968 ==========
# ========== 60 ===== ===== test accuracy is  0.964 ==========
# ========== 80 ===== ===== test accuracy is  0.964 ==========
# ========== 100 ===== ===== test accuracy is  0.968 ==========
# ========== 120 ===== ===== test accuracy is  0.964 ==========
# ========== 140 ===== ===== test accuracy is  0.962 ==========
# ========== 160 ===== ===== test accuracy is  0.966 ==========
# ========== 180 ===== ===== test accuracy is  0.962 ==========
# ========== 200 ===== ===== test accuracy is  0.968 ==========
# ========== 220 ===== ===== test accuracy is  0.968 ==========
# ========== 240 ===== ===== test accuracy is  0.972 ==========
# ========== 260 ===== ===== test accuracy is  0.972 ==========
# ========== 280 ===== ===== test accuracy is  0.974 ==========
# ========== 300 ===== ===== test accuracy is  0.97 ==========
# ========== 320 ===== ===== test accuracy is  0.97 ==========
# ========== 340 ===== ===== test accuracy is  0.974 ==========
# ========== 360 ===== ===== test accuracy is  0.974 ==========
# ========== 380 ===== ===== test accuracy is  0.96 ==========
# ========== 400 ===== ===== test accuracy is  0.976 ==========
# ========== 420 ===== ===== test accuracy is  0.966 ==========
# ========== 440 ===== ===== test accuracy is  0.976 ==========
# ========== 460 ===== ===== test accuracy is  0.968 ==========
# ========== 480 ===== ===== test accuracy is  0.97 ==========
# ========== 500 ===== ===== test accuracy is  0.98 ==========
# ========== 520 ===== ===== test accuracy is  0.964 ==========
# ========== 540 ===== ===== test accuracy is  0.96 ==========
# ========== 560 ===== ===== test accuracy is  0.966 ==========
# ========== 580 ===== ===== test accuracy is  0.97 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.956 ==========
# ========== 640 ===== ===== test accuracy is  0.96 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.962 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.972 ==========
# ========== 740 ===== ===== test accuracy is  0.976 ==========
# ========== 760 ===== ===== test accuracy is  0.966 ==========
# ========== 780 ===== ===== test accuracy is  0.962 ==========
# ========== 800 ===== ===== test accuracy is  0.982 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.972 ==========
# ========== 860 ===== ===== test accuracy is  0.972 ==========
# ========== 880 ===== ===== test accuracy is  0.96 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.98 ==========
# ========== 940 ===== ===== test accuracy is  0.958 ==========
# ========== 960 ===== ===== test accuracy is  0.976 ==========
# ========== 980 ===== ===== test accuracy is  0.97 ==========
# ========== 1000 ===== ===== test accuracy is  0.978 ==========
# ========== 1020 ===== ===== test accuracy is  0.982 ==========
# ========== 1040 ===== ===== test accuracy is  0.984 ==========
# ========== 1060 ===== ===== test accuracy is  0.972 ==========
# ========== 1080 ===== ===== test accuracy is  0.964 ==========
# ========== 1100 ===== ===== test accuracy is  0.974 ==========
# ========== 1120 ===== ===== test accuracy is  0.97 ==========
# ========== 1140 ===== ===== test accuracy is  0.97 ==========
# ========== 1160 ===== ===== test accuracy is  0.972 ==========
# ========== 1180 ===== ===== test accuracy is  0.964 ==========
